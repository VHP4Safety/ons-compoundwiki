# %% [markdown]
# This workflow shows how Python can be used to aggregated database identifiers and physicochemical properties, starting with the SMILES line notation of a chemical compound. The first thing it will do is lookup the record for that compound in the VHP4Safety Compound Wiki. Using mappings to Wikidata it will then retrieve additional information.
#
# This workflow was developed as part of the VHP4Safety project by Maastricht University. The tip for using the `wikidataintegrator` came from Andra.
#
# **Installation**
#
# First, we need to install the required software.

# %%
# !apt install maven openjdk-11-jdk
# !pip install scyjava
# !pip install wikidataintegrator
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaopalliance-java libapache-pom-java
#   libatinject-jsr330-api-java libatk-wrapper-java libatk-wrapper-java-jni libcdi-api-java
#   libcommons-cli-java libcommons-io-java libcommons-lang3-java libcommons-parent-java libfontenc1
#   libgeronimo-annotation-1.3-spec-java libgeronimo-interceptor-3.0-spec-java libguava-java
#   libguice-java libhawtjni-runtime-java libice-dev libjansi-java libjansi-native-java
#   libjsr305-java libmaven-parent-java libmaven-resolver-java libmaven-shared-utils-java
#   libmaven3-core-java libplexus-cipher-java libplexus-classworlds-java
#   libplexus-component-annotations-java libplexus-interpolation-java libplexus-sec-dispatcher-java
#   libplexus-utils2-java libsisu-inject-java libsisu-plexus-java libslf4j-java libsm-dev
#   libwagon-file-java libwagon-http-shaded-java libwagon-provider-api-java libxkbfile1 libxt-dev
#   libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   libaopalliance-java-doc libatinject-jsr330-api-java-doc libel-api-java libcommons-io-java-doc
#   libcommons-lang3-java-doc libasm-java libcglib-java libice-doc libjsr305-java-doc
#   libmaven-shared-utils-java-doc liblogback-java libplexus-classworlds-java-doc
#   libplexus-sec-dispatcher-java-doc libplexus-utils2-java-doc junit4 testng libcommons-logging-java
#   liblog4j1.2-java libsm-doc libxt-doc openjdk-11-demo openjdk-11-source visualvm mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaopalliance-java libapache-pom-java
#   libatinject-jsr330-api-java libatk-wrapper-java libatk-wrapper-java-jni libcdi-api-java
#   libcommons-cli-java libcommons-io-java libcommons-lang3-java libcommons-parent-java libfontenc1
#   libgeronimo-annotation-1.3-spec-java libgeronimo-interceptor-3.0-spec-java libguava-java
#   libguice-java libhawtjni-runtime-java libice-dev libjansi-java libjansi-native-java
#   libjsr305-java libmaven-parent-java libmaven-resolver-java libmaven-shared-utils-java
#   libmaven3-core-java libplexus-cipher-java libplexus-classworlds-java
#   libplexus-component-annotations-java libplexus-interpolation-java libplexus-sec-dispatcher-java
#   libplexus-utils2-java libsisu-inject-java libsisu-plexus-java libslf4j-java libsm-dev
#   libwagon-file-java libwagon-http-shaded-java libwagon-provider-api-java libxkbfile1 libxt-dev
#   libxtst6 libxxf86dga1 maven openjdk-11-jdk openjdk-11-jre x11-utils
# 0 upgraded, 47 newly installed, 0 to remove and 49 not upgraded.
# Need to get 15.8 MB of archives.
# After this operation, 29.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libatinject-jsr330-api-java all 1.0+ds1-5 [5,348 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgeronimo-interceptor-3.0-spec-java all 1.0.1-4fakesync [8,616 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcdi-api-java all 1.2-3 [54.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-cli-java all 1.4-2 [55.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-io-java all 2.11.0-2 [297 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-lang3-java all 3.11-1 [526 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgeronimo-annotation-1.3-spec-java all 1.3-1 [11.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjsr305-java all 0.1~+svn49-11 [27.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libguava-java all 29.0-6 [2,418 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaopalliance-java all 20070526-6 [9,084 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libguice-java all 4.2.3-2 [1,434 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhawtjni-runtime-java all 1.17-1 [28.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjansi-native-java all 1.8-1 [23.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjansi-java all 1.18-1 [56.8 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmaven-parent-java all 31-2 [5,140 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-utils2-java all 3.3.0-1 [250 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwagon-provider-api-java all 3.3.4-1 [48.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmaven-resolver-java all 1.4.2-3build1 [555 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmaven-shared-utils-java all 3.3.0-1ubuntu0.22.04.1 [148 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-cipher-java all 1.8-2 [15.1 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-classworlds-java all 2.6.0-1 [49.4 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-component-annotations-java all 2.1.0-1 [6,564 B]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-interpolation-java all 1.26-1 [76.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libplexus-sec-dispatcher-java all 1.4-4 [28.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libslf4j-java all 1.7.32-1 [141 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsisu-inject-java all 0.3.4-2 [347 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsisu-plexus-java all 0.3.4-3 [181 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmaven3-core-java all 3.6.3-5 [1,535 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwagon-file-java all 3.3.4-1 [7,928 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwagon-http-shaded-java all 3.3.4-1 [1,855 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 maven all 3.6.3-5 [17.8 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.25+9-1ubuntu1~22.04 [216 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jdk amd64 11.0.25+9-1ubuntu1~22.04 [1,334 kB]
# Fetched 15.8 MB in 2s (9,731 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 124561 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../02-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libatinject-jsr330-api-java.
# Preparing to unpack .../03-libatinject-jsr330-api-java_1.0+ds1-5_all.deb ...
# Unpacking libatinject-jsr330-api-java (1.0+ds1-5) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../04-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../05-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../06-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../07-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../08-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../09-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../10-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgeronimo-interceptor-3.0-spec-java.
# Preparing to unpack .../11-libgeronimo-interceptor-3.0-spec-java_1.0.1-4fakesync_all.deb ...
# Unpacking libgeronimo-interceptor-3.0-spec-java (1.0.1-4fakesync) ...
# Selecting previously unselected package libcdi-api-java.
# Preparing to unpack .../12-libcdi-api-java_1.2-3_all.deb ...
# Unpacking libcdi-api-java (1.2-3) ...
# Selecting previously unselected package libcommons-cli-java.
# Preparing to unpack .../13-libcommons-cli-java_1.4-2_all.deb ...
# Unpacking libcommons-cli-java (1.4-2) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../14-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-io-java.
# Preparing to unpack .../15-libcommons-io-java_2.11.0-2_all.deb ...
# Unpacking libcommons-io-java (2.11.0-2) ...
# Selecting previously unselected package libcommons-lang3-java.
# Preparing to unpack .../16-libcommons-lang3-java_3.11-1_all.deb ...
# Unpacking libcommons-lang3-java (3.11-1) ...
# Selecting previously unselected package libgeronimo-annotation-1.3-spec-java.
# Preparing to unpack .../17-libgeronimo-annotation-1.3-spec-java_1.3-1_all.deb ...
# Unpacking libgeronimo-annotation-1.3-spec-java (1.3-1) ...
# Selecting previously unselected package libjsr305-java.
# Preparing to unpack .../18-libjsr305-java_0.1~+svn49-11_all.deb ...
# Unpacking libjsr305-java (0.1~+svn49-11) ...
# Selecting previously unselected package libguava-java.
# Preparing to unpack .../19-libguava-java_29.0-6_all.deb ...
# Unpacking libguava-java (29.0-6) ...
# Selecting previously unselected package libaopalliance-java.
# Preparing to unpack .../20-libaopalliance-java_20070526-6_all.deb ...
# Unpacking libaopalliance-java (20070526-6) ...
# Selecting previously unselected package libguice-java.
# Preparing to unpack .../21-libguice-java_4.2.3-2_all.deb ...
# Unpacking libguice-java (4.2.3-2) ...
# Selecting previously unselected package libhawtjni-runtime-java.
# Preparing to unpack .../22-libhawtjni-runtime-java_1.17-1_all.deb ...
# Unpacking libhawtjni-runtime-java (1.17-1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../23-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libjansi-native-java.
# Preparing to unpack .../24-libjansi-native-java_1.8-1_all.deb ...
# Unpacking libjansi-native-java (1.8-1) ...
# Selecting previously unselected package libjansi-java.
# Preparing to unpack .../25-libjansi-java_1.18-1_all.deb ...
# Unpacking libjansi-java (1.18-1) ...
# Selecting previously unselected package libmaven-parent-java.
# Preparing to unpack .../26-libmaven-parent-java_31-2_all.deb ...
# Unpacking libmaven-parent-java (31-2) ...
# Selecting previously unselected package libplexus-utils2-java.
# Preparing to unpack .../27-libplexus-utils2-java_3.3.0-1_all.deb ...
# Unpacking libplexus-utils2-java (3.3.0-1) ...
# Selecting previously unselected package libwagon-provider-api-java.
# Preparing to unpack .../28-libwagon-provider-api-java_3.3.4-1_all.deb ...
# Unpacking libwagon-provider-api-java (3.3.4-1) ...
# Selecting previously unselected package libmaven-resolver-java.
# Preparing to unpack .../29-libmaven-resolver-java_1.4.2-3build1_all.deb ...
# Unpacking libmaven-resolver-java (1.4.2-3build1) ...
# Selecting previously unselected package libmaven-shared-utils-java.
# Preparing to unpack .../30-libmaven-shared-utils-java_3.3.0-1ubuntu0.22.04.1_all.deb ...
# Unpacking libmaven-shared-utils-java (3.3.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libplexus-cipher-java.
# Preparing to unpack .../31-libplexus-cipher-java_1.8-2_all.deb ...
# Unpacking libplexus-cipher-java (1.8-2) ...
# Selecting previously unselected package libplexus-classworlds-java.
# Preparing to unpack .../32-libplexus-classworlds-java_2.6.0-1_all.deb ...
# Unpacking libplexus-classworlds-java (2.6.0-1) ...
# Selecting previously unselected package libplexus-component-annotations-java.
# Preparing to unpack .../33-libplexus-component-annotations-java_2.1.0-1_all.deb ...
# Unpacking libplexus-component-annotations-java (2.1.0-1) ...
# Selecting previously unselected package libplexus-interpolation-java.
# Preparing to unpack .../34-libplexus-interpolation-java_1.26-1_all.deb ...
# Unpacking libplexus-interpolation-java (1.26-1) ...
# Selecting previously unselected package libplexus-sec-dispatcher-java.
# Preparing to unpack .../35-libplexus-sec-dispatcher-java_1.4-4_all.deb ...
# Unpacking libplexus-sec-dispatcher-java (1.4-4) ...
# Selecting previously unselected package libslf4j-java.
# Preparing to unpack .../36-libslf4j-java_1.7.32-1_all.deb ...
# Unpacking libslf4j-java (1.7.32-1) ...
# Selecting previously unselected package libsisu-inject-java.
# Preparing to unpack .../37-libsisu-inject-java_0.3.4-2_all.deb ...
# Unpacking libsisu-inject-java (0.3.4-2) ...
# Selecting previously unselected package libsisu-plexus-java.
# Preparing to unpack .../38-libsisu-plexus-java_0.3.4-3_all.deb ...
# Unpacking libsisu-plexus-java (0.3.4-3) ...
# Selecting previously unselected package libmaven3-core-java.
# Preparing to unpack .../39-libmaven3-core-java_3.6.3-5_all.deb ...
# Unpacking libmaven3-core-java (3.6.3-5) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../40-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libwagon-file-java.
# Preparing to unpack .../41-libwagon-file-java_3.3.4-1_all.deb ...
# Unpacking libwagon-file-java (3.3.4-1) ...
# Selecting previously unselected package libwagon-http-shaded-java.
# Preparing to unpack .../42-libwagon-http-shaded-java_3.3.4-1_all.deb ...
# Unpacking libwagon-http-shaded-java (3.3.4-1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../43-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package maven.
# Preparing to unpack .../44-maven_3.6.3-5_all.deb ...
# Unpacking maven (3.6.3-5) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../45-openjdk-11-jre_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Selecting previously unselected package openjdk-11-jdk:amd64.
# Preparing to unpack .../46-openjdk-11-jdk_11.0.25+9-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jdk:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up libslf4j-java (1.7.32-1) ...
# Setting up libplexus-utils2-java (3.3.0-1) ...
# Setting up libplexus-classworlds-java (2.6.0-1) ...
# Setting up libjsr305-java (0.1~+svn49-11) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libaopalliance-java (20070526-6) ...
# Setting up libcommons-cli-java (1.4-2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libplexus-component-annotations-java (2.1.0-1) ...
# Setting up openjdk-11-jre:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# Setting up libplexus-cipher-java (1.8-2) ...
# Setting up libgeronimo-annotation-1.3-spec-java (1.3-1) ...
# Setting up libgeronimo-interceptor-3.0-spec-java (1.0.1-4fakesync) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up libatinject-jsr330-api-java (1.0+ds1-5) ...
# Setting up libplexus-interpolation-java (1.26-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libplexus-sec-dispatcher-java (1.4-4) ...
# Setting up openjdk-11-jdk:amd64 (11.0.25+9-1ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libwagon-http-shaded-java (3.3.4-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libcdi-api-java (1.2-3) ...
# Setting up libhawtjni-runtime-java (1.17-1) ...
# Setting up libwagon-provider-api-java (3.3.4-1) ...
# Setting up libmaven-parent-java (31-2) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libsisu-inject-java (0.3.4-2) ...
# Setting up libsisu-plexus-java (0.3.4-3) ...
# Setting up libmaven-resolver-java (1.4.2-3build1) ...
# Setting up libguava-java (29.0-6) ...
# Setting up libcommons-lang3-java (3.11-1) ...
# Setting up libjansi-native-java (1.8-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libwagon-file-java (3.3.4-1) ...
# Setting up libcommons-io-java (2.11.0-2) ...
# Setting up libguice-java (4.2.3-2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libjansi-java (1.18-1) ...
# Setting up libmaven-shared-utils-java (3.3.0-1ubuntu0.22.04.1) ...
# Setting up libmaven3-core-java (3.6.3-5) ...
# Setting up maven (3.6.3-5) ...
# update-alternatives: using /usr/share/maven/bin/mvn to provide /usr/bin/mvn (mvn) in auto mode
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Collecting scyjava
#   Downloading scyjava-1.10.1-py3-none-any.whl.metadata (23 kB)
# Collecting jpype1<=1.5.0,>=1.3.0 (from scyjava)
#   Downloading JPype1-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting jgo (from scyjava)
#   Downloading jgo-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from jpype1<=1.5.0,>=1.3.0->scyjava) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from jgo->scyjava) (5.9.5)
# Downloading scyjava-1.10.1-py3-none-any.whl (30 kB)
# Downloading JPype1-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 27.2 MB/s eta 0:00:00
# Downloading jgo-1.0.6-py3-none-any.whl (15 kB)
# Installing collected packages: jpype1, jgo, scyjava
# Successfully installed jgo-1.0.6 jpype1-1.5.0 scyjava-1.10.1
# Collecting wikidataintegrator
#   Downloading wikidataintegrator-0.9.30-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wikidataintegrator) (2.32.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from wikidataintegrator) (2.8.2)
# Collecting simplejson (from wikidataintegrator)
#   Downloading simplejson-3.19.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from wikidataintegrator) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from wikidataintegrator) (4.67.1)
# Collecting mwoauth (from wikidataintegrator)
#   Downloading mwoauth-0.4.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.11/dist-packages (from wikidataintegrator) (3.2.2)
# Collecting jsonasobj (from wikidataintegrator)
#   Downloading jsonasobj-1.3.1-py3-none-any.whl.metadata (995 bytes)
# Collecting pyshex (from wikidataintegrator)
#   Downloading PyShEx-0.8.1-py3-none-any.whl.metadata (1.0 kB)
# Collecting backoff (from wikidataintegrator)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting shexer (from wikidataintegrator)
#   Downloading shexer-2.5.9-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: PyJWT>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from mwoauth->wikidataintegrator) (2.10.1)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from mwoauth->wikidataintegrator) (1.3.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->wikidataintegrator) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->wikidataintegrator) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->wikidataintegrator) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->wikidataintegrator) (1.17.0)
# Collecting cfgraph>=0.2.1 (from pyshex->wikidataintegrator)
#   Downloading CFGraph-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from pyshex->wikidataintegrator) (5.2.0)
# Collecting pyshexc==0.9.1 (from pyshex->wikidataintegrator)
#   Downloading PyShExC-0.9.1-py2.py3-none-any.whl.metadata (940 bytes)
# Collecting rdflib-shim (from pyshex->wikidataintegrator)
#   Downloading rdflib_shim-1.0.3-py3-none-any.whl.metadata (918 bytes)
# Collecting shexjsg>=0.8.2 (from pyshex->wikidataintegrator)
#   Downloading ShExJSG-0.8.2-py2.py3-none-any.whl.metadata (997 bytes)
# Collecting sparqlslurper>=0.5.1 (from pyshex->wikidataintegrator)
#   Downloading sparqlslurper-0.5.1-py3-none-any.whl.metadata (430 bytes)
# Collecting sparqlwrapper>=1.8.5 (from pyshex->wikidataintegrator)
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pyshex->wikidataintegrator) (2.3.0)
# Collecting antlr4-python3-runtime~=4.9.3 (from pyshexc==0.9.1->pyshex->wikidataintegrator)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyjsg>=0.11.10 (from pyshexc==0.9.1->pyshex->wikidataintegrator)
#   Downloading PyJSG-0.11.10-py3-none-any.whl.metadata (978 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wikidataintegrator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wikidataintegrator) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wikidataintegrator) (2024.12.14)
# Requirement already satisfied: Flask in /usr/local/lib/python3.11/dist-packages (from shexer->wikidataintegrator) (3.1.0)
# Collecting Flask-Cors (from shexer->wikidataintegrator)
#   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting rdflib (from shexer->wikidataintegrator)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting wlighter (from shexer->wikidataintegrator)
#   Downloading wlighter-1.0.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plantuml (from shexer->wikidataintegrator)
#   Downloading plantuml-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting python-xz (from shexer->wikidataintegrator)
#   Downloading python_xz-0.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib->shexer->wikidataintegrator) (3.2.1)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer->wikidataintegrator) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer->wikidataintegrator) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer->wikidataintegrator) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer->wikidataintegrator) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer->wikidataintegrator) (1.9.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.11/dist-packages (from plantuml->shexer->wikidataintegrator) (0.22.0)
# Collecting rdflib-jsonld==0.6.1 (from rdflib-shim->pyshex->wikidataintegrator)
#   Downloading rdflib_jsonld-0.6.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->Flask->shexer->wikidataintegrator) (3.0.2)
# Downloading wikidataintegrator-0.9.30-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 kB 9.5 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading jsonasobj-1.3.1-py3-none-any.whl (4.4 kB)
# Downloading mwoauth-0.4.0-py3-none-any.whl (12 kB)
# Downloading PyShEx-0.8.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 4.1 MB/s eta 0:00:00
# Downloading PyShExC-0.9.1-py2.py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 5.9 MB/s eta 0:00:00
# Downloading shexer-2.5.9-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 13.9 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.7/144.7 kB 11.4 MB/s eta 0:00:00
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 29.6 MB/s eta 0:00:00
# Downloading ShExJSG-0.8.2-py2.py3-none-any.whl (14 kB)
# Downloading sparqlslurper-0.5.1-py3-none-any.whl (6.6 kB)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Downloading plantuml-0.3.0-py3-none-any.whl (5.8 kB)
# Downloading python_xz-0.5.0-py3-none-any.whl (20 kB)
# Downloading rdflib_shim-1.0.3-py3-none-any.whl (5.2 kB)
# Downloading rdflib_jsonld-0.6.1-py2.py3-none-any.whl (16 kB)
# Downloading PyJSG-0.11.10-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 6.8 MB/s eta 0:00:00
# Building wheels for collected packages: cfgraph, wlighter, antlr4-python3-runtime
#   Building wheel for cfgraph (setup.py) ... done
#   Created wheel for cfgraph: filename=CFGraph-0.2.1-py3-none-any.whl size=2214 sha256=683ccdc89874e7da5372beed40244a1104d503af7918259d5ed7be5f87d91f36
#   Stored in directory: /root/.cache/pip/wheels/8b/ac/8f/0f5b041561f10e6db39796e4ad11011b8f5a4b0a0ed74a5e61
#   Building wheel for wlighter (setup.py) ... done
#   Created wheel for wlighter: filename=wlighter-1.0.1-py3-none-any.whl size=5840 sha256=a5e7de23cbbb14fea6705e06ae04f0704479899d212558ccca1dd31902eebdf9
#   Stored in directory: /root/.cache/pip/wheels/a7/99/fc/827abe031e1eb32a25e3bda1affff5a8adccfecf52d5548425
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=a9575adac13dea82f9869b73c51e26671f5b3586fbd8d2566ef2a8548c79190d
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built cfgraph wlighter antlr4-python3-runtime
# Installing collected packages: jsonasobj, antlr4-python3-runtime, simplejson, rdflib, python-xz, pyjsg, backoff, wlighter, sparqlwrapper, shexjsg, rdflib-jsonld, plantuml, cfgraph, rdflib-shim, mwoauth, Flask-Cors, sparqlslurper, shexer, pyshexc, pyshex, wikidataintegrator
# Successfully installed Flask-Cors-5.0.0 antlr4-python3-runtime-4.9.3 backoff-2.2.1 cfgraph-0.2.1 jsonasobj-1.3.1 mwoauth-0.4.0 plantuml-0.3.0 pyjsg-0.11.10 pyshex-0.8.1 pyshexc-0.9.1 python-xz-0.5.0 rdflib-7.1.3 rdflib-jsonld-0.6.1 rdflib-shim-1.0.3 shexer-2.5.9 shexjsg-0.8.2 simplejson-3.19.3 sparqlslurper-0.5.1 sparqlwrapper-2.0.0 wikidataintegrator-0.9.30 wlighter-1.0.1

# %%
from scyjava import config, jimport
from wikidataintegrator import wdi_core

config.endpoints.append('org.openscience.cdk:cdk-bundle:2.9')
SmilesParser = jimport('org.openscience.cdk.smiles.SmilesParser')
Builder = jimport('org.openscience.cdk.silent.SilentChemObjectBuilder')
InChIGeneratorFactory = jimport('org.openscience.cdk.inchi.InChIGeneratorFactory')
INCHI_RET =  jimport('net.sf.jniinchi.INCHI_RET')

# %% [markdown]
# **SMILES to InChIKey**
#
# The SMILES is a line notation describing a chemical structure, but not a unique identifier. Using the SMILES string for a lookup will gnerally result in false negatives. The InChI and InChIkey have been developed for this. We therefore first convert the SMILES into a InChIKey.

# %%
sp = SmilesParser(Builder.getInstance())
mol = sp.parseSmiles("CC(=C)[C@H]1CC2=C(O1)C=CC3=C2O[C@@H]4COC5=CC(=C(C=C5[C@@H]4C3=O)OC)OC")
print(f"This compound has {mol.getAtomCount()} atoms.")

factory = InChIGeneratorFactory.getInstance();
generator = factory.getInChIGenerator(mol);
if generator.getReturnStatus() == INCHI_RET.OKAY:
  inchiObj = generator.getInchi()
  print(f"This compound has this InChI: {inchiObj}")
  inchiKey = generator.getInchiKey()
  print(f"  and this InChIKey: {inchiKey}")
# Out:
# This compound has 29 atoms.
# This compound has this InChI: InChI=1S/C23H22O6/c1-11(2)16-8-14-15(28-16)6-5-12-22(24)21-13-7-18(25-3)19(26-4)9-17(13)27-10-20(21)29-23(12)14/h5-7,9,16,20-21H,1,8,10H2,2-4H3/t16-,20-,21+/m1/s1
#   and this InChIKey: JUVIOZPCNVVQFO-HBGVWJBISA-N

# %% [markdown]
# **Using the InChIKey to find the VHP4Safety Compound Wikidata record**
#
# The below code examples uses the calculated InChIKey to do an exact match lookup with the SPARQL API.

# %%
# SPARQL endpoint URLs
compoundwikiEP = "https://compoundcloud.wikibase.cloud/query/sparql"

sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>

SELECT ?cmp ?cmpLabel ?inchiKey
WHERE {
  VALUES ?inchiKey { "''' + str(inchiKey) + '''" }
  # ?cmp wdt:P10 ?inchiKey .
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''

df = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
df.loc[:,["cmp", "cmpLabel", "inchiKey"]]
# Out:
#                                                cmp  cmpLabel  \
# 0  https://compoundcloud.wikibase.cloud/entity/Q38  rotenone
#
#                       inchiKey
# 0  JUVIOZPCNVVQFO-HBGVWJBISA-N

# %% [markdown]
# We can extract the Compound Wiki identifier with the following code:

# %%
vhpID = df.at[0,'cmp'][44:]
vhpID
# Out:
# 'Q38'

# %% [markdown]
# **External Databases**
#
# The VHP4Safety Compound Wikidata indexes a few databases not indexed by other resources or otherwise specific to toxicology. The follow query looks up the external identifiers.

# %%
sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>

SELECT ?propertyLabel ?identifier
WHERE {
  VALUES ?property { wd:P4 wd:P13 wd:P19 wd:P22 wd:P23 wd:P26 wd:P27 wd:P28 wd:P36 wd:P41 }
  # ?property wikibase:directClaim ?identifierProp .
  OPTIONAL { wd:''' + vhpID + ''' ?identifierProp ?identifier }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''

identifiers = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
identifiers.loc[:,["propertyLabel","identifier"]]
# Out:
#                    propertyLabel                              identifier
# 0                   ToxBank Wiki  https://wiki.toxbank.net/wiki/Rotenone
# 1                    PubChem CID                                    6758
# 2  xenobiotic metabolism pathway                                  WP5486
# 3     DSSTOX compound identifier                                     NaN
# 4            CAS Registry Number                                 83-79-4
# 5        JRC Data Catalogue Term                                rotenone
# 6                        KEGG ID                                     NaN
# 7                       ChEBI ID                                     NaN
# 8           AOP-Wiki Stressor ID                                      50
# 9                      ChEMBL ID                                     NaN

# %% [markdown]
# **Chemical properties**
#
# The VHP4Safety Compound Wikidata also provides a few properties. This query fetches those:

# %%
sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>

SELECT ?propertyLabel ?value
WHERE {
  VALUES ?property { wd:P3 wd:P2 wd:P32 }
  # ?property wikibase:directClaim ?valueProp .
  OPTIONAL { wd:''' + vhpID + ''' ?valueProp ?value }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''

properties = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
properties.loc[:,["propertyLabel","value"]]
# Out:
#                          propertyLabel     value
# 0                                 mass  394.4181
# 1                     chemical formula  C₂₃H₂₂O₆
# 2  octanol-water partition coefficient       NaN

# %% [markdown]
# **Information from Wikidata**
#
# The VHP4Safety Compound Wiki is linked to Wikidata via `wd:P5` and Wikidata provides a lot more information which can be retrieved with their SPARQL API. We first get the Wikidata identifier:

# %%
sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>

SELECT ?wikidata
WHERE {
  wd:P5 wikibase:directClaim ?identifierProp .
  wd:''' + vhpID + ''' ?identifierProp ?wikidata .
}
'''

identifiers = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
wikidataID = identifiers.at[0,'wikidata']
wikidataID
# Out:
# 'Q412388'

# %% [markdown]
# Now that we know the Wikidata identifier, we can use this to get additional information. For example, Wikidata has many more external identifiers, which we can retrieve with SPARQL too:

# %%
sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>
PREFIX wid: <http://www.wikidata.org/entity/>
PREFIX widt: <http://www.wikidata.org/prop/direct/>

SELECT ?IdentifierLabel ?Value ?url
WHERE {
  wd:P5 wikibase:directClaim ?identifierProp .
  wd:''' + vhpID + ''' ?identifierProp ?wikidata .
  BIND (iri(CONCAT("http://www.wikidata.org/entity/", ?wikidata)) AS ?qid)
  SERVICE <https://query.wikidata.org/sparql> {
    # ?qid ?IDdir ?Value .
    # ?Identifier wikibase:directClaim ?IDdir ;
            widt:P31 wid:Q19833835 ;
            rdfs:label ?IdentifierLabel .
    FILTER ( lang(?IdentifierLabel) = 'en' )
    OPTIONAL {
      # ?Identifier widt:P1630 ?formatterurl .
    }
    FILTER (?Identifier != wid:P233)
    FILTER (?Identifier != wid:P234)
    FILTER (?Identifier != wid:P2017)
    BIND(IRI(REPLACE(?formatterurl, '\\\\$1', str(?Value))) AS ?url).
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''

moreDatabases = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
moreDatabases.loc[:,["IdentifierLabel","Value","url"]]
# Out:
#                  IdentifierLabel                                    Value  \
# 0                      ChEMBL ID                             CHEMBL429023
# 1                           UNII                               03L9OT429T
# 2                   RTECS number                                DJ2800000
# 3                        KEGG ID                                   C07593
# 4                       ChEBI ID                                    28201
# 5                  ChemSpider ID                                     6500
# 6                    PubChem CID                                     6758
# 7            CAS Registry Number                                  83-79-4
# 8                      EC number                                201-501-9
# 9                       InChIKey              JUVIOZPCNVVQFO-HBGVWJBISA-N
# 10        Reaxys registry number                                    99070
# 11  Human Metabolome Database ID                              HMDB0034436
# 12                       HSDB ID                                     1762
# 13                 LIPID MAPS ID                             LMPK12060007
# 14                   KNApSAcK ID                                C00002568
# 15                   DrugBank ID                                  DB11457
# 16         NIOSH Pocket Guide ID                                     0548
# 17    ECHA Substance Infocard ID                              100.001.365
# 18                    NSC number                                    26258
# 19                    NSC number                                     8505
# 20                 SureChEMBL ID                             SCHEMBL42253
# 21           DSSTox substance ID                            DTXSID6021248
# 22         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000116
# 23         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000117
# 24         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000118
# 25         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000119
# 26         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000120
# 27         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000121
# 28         MassBank accession ID  MSBNK-MPI_for_Chemical_Ecology-CE000122
# 29         MassBank accession ID                 MSBNK-IPB_Halle-PB005741
# 30         MassBank accession ID                 MSBNK-IPB_Halle-PB005742
# 31         MassBank accession ID                 MSBNK-IPB_Halle-PB005743
# 32           UniChem compound ID                                   128707
# 33           Probes And Drugs ID                                 PD002240
# 34            CAMEO Chemicals ID                                    20997
# 35     PesticideInfo chemical ID                                  PRI5581
#
#                                                   url
# 0   https://www.ebi.ac.uk/chembl/compound_report_c...
# 1   https://gsrs.ncats.nih.gov/ginas/app/beta/subs...
# 2                                                 NaN
# 3                    https://www.kegg.jp/entry/C07593
# 4   https://www.ebi.ac.uk/chebi/searchId.do?chebiI...
# 5   https://www.chemspider.com/Chemical-Structure....
# 6      https://pubchem.ncbi.nlm.nih.gov/compound/6758
# 7   https://commonchemistry.cas.org/detail?cas_rn=...
# 8   https://echa.europa.eu/information-on-chemical...
# 9   https://www.ncbi.nlm.nih.gov/sites/entrez?cmd=...
# 10                                                NaN
# 11        https://www.hmdb.ca/metabolites/HMDB0034436
# 12  https://pubchem.ncbi.nlm.nih.gov/source/hsdb/1762
# 13  https://www.lipidmaps.org/data/structure/LMSDS...
# 14  http://www.knapsackfamily.com/knapsack_core/in...
# 15              https://go.drugbank.com/drugs/DB11457
# 16         http://www.cdc.gov/niosh/npg/npgd0548.html
# 17  https://echa.europa.eu/substance-information/-...
# 18  https://dtp.cancer.gov/dtpstandard/servlet/dwi...
# 19  https://dtp.cancer.gov/dtpstandard/servlet/dwi...
# 20   https://www.surechembl.org/chemical/SCHEMBL42253
# 21  https://comptox.epa.gov/dashboard/chemical/det...
# 22  https://massbank.eu/MassBank/RecordDisplay?id=...
# 23  https://massbank.eu/MassBank/RecordDisplay?id=...
# 24  https://massbank.eu/MassBank/RecordDisplay?id=...
# 25  https://massbank.eu/MassBank/RecordDisplay?id=...
# 26  https://massbank.eu/MassBank/RecordDisplay?id=...
# 27  https://massbank.eu/MassBank/RecordDisplay?id=...
# 28  https://massbank.eu/MassBank/RecordDisplay?id=...
# 29  https://massbank.eu/MassBank/RecordDisplay?id=...
# 30  https://massbank.eu/MassBank/RecordDisplay?id=...
# 31  https://massbank.eu/MassBank/RecordDisplay?id=...
# 32  https://www.ebi.ac.uk/unichem/compoundsources?...
# 33     https://www.probes-drugs.org/compound/PD002240
# 34     https://cameochemicals.noaa.gov/chemical/20997
# 35     https://www.pesticideinfo.org/chemical/PRI5581

# %% [markdown]
# Likewise, we can request physicochemical properties:

# %%
sparqlquery = '''
PREFIX wd: <https://compoundcloud.wikibase.cloud/entity/>
PREFIX wdt: <https://compoundcloud.wikibase.cloud/prop/direct/>
PREFIX wid: <http://www.wikidata.org/entity/>
PREFIX widt: <http://www.wikidata.org/prop/direct/>
PREFIX prov: <http://www.w3.org/ns/prov#>

SELECT ?propEntityLabel ?value ?unitsLabel ?source ?doi
WHERE {
  wd:P5 wikibase:directClaim ?identifierProp .
  wd:''' + vhpID + ''' ?identifierProp ?wikidata .
  BIND (iri(CONCAT("http://www.wikidata.org/entity/", ?wikidata)) AS ?qid)
  SERVICE <https://query.wikidata.org/sparql> {
    # ?qid ?propp ?statement .
    # ?statement a wikibase:BestRank ;
      # ?proppsv [
        wikibase:quantityAmount ?value ;
        wikibase:quantityUnit ?units
      ] .
    OPTIONAL {
      # ?statement prov:wasDerivedFrom/pr:P248 ?source .
      OPTIONAL { ?source wdt:P356 ?doi . }
    }
    # ?property wikibase:claim ?propp ;
            wikibase:statementValue ?proppsv ;
            widt:P1629 ?propEntity ;
            widt:P31 wid:Q21077852 .
    # ?propEntity rdfs:label ?propEntityLabel .
    FILTER ( lang(?propEntityLabel) = 'en' )
    # ?units rdfs:label ?unitsLabel .
    FILTER ( lang(?unitsLabel) = 'en' )
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
'''

moreDatabases = wdi_core.WDFunctionsEngine.execute_sparql_query(sparqlquery, endpoint=compoundwikiEP, as_dataframe=True)
moreDatabases.loc[:,["propEntityLabel","value","unitsLabel","source"]]
# Out:
#                            propEntityLabel       value  \
# 0                             mass density     1.27000
# 1                            melting point   330.00000
# 2  Immediately dangerous to life or health  2500.00000
# 3      time-weighted average concentration     5.00000
# 4                           vapor pressure     0.00004
# 5                            boiling point   215.00000
# 6                                     mass   394.14200
#
#                   unitsLabel                                  source
# 0  gram per cubic centimetre                                     NaN
# 1          degree Fahrenheit                                     NaN
# 2  milligram per cubic metre                                     NaN
# 3  milligram per cubic metre                                     NaN
# 4      millimetre of mercury                                     NaN
# 5             degree Celsius     http://www.wikidata.org/entity/Q328
# 6                     dalton  http://www.wikidata.org/entity/Q278487

# %% [markdown]
# The last command may fail, depending on the available data. The SPARQL clearly returns a DOI, but panda removes empty columns, it seems, so depending on the data, the "doi" column may be there or not.
